# %% [markdown]
# Question 1-1

# %%
print("Welcome to Python Programming")
print("Welcome", "to", "Python", "Programming")
print("Welcome", "to", "Python", "Programming", sep=" ")
print("Welcome", "to", "Python", "Programming", sep="-")
print("Welcome", "to", "Python", "Programming", sep="")
# Out:
# Welcome to Python Programming
# Welcome to Python Programming
# Welcome to Python Programming
# Welcome-to-Python-Programming
# WelcometoPythonProgramming

# %% [markdown]
# Question 1-2

# %%
print("Welcome", "to")
print("Python", "Programming")
print("Welcome", "to", end="\n")
print("Python", "Programming")
print("Welcome", "to", end=" ")
print("Python", "Programming")
print("Welcome", "to", end="-")
print("Python", "Programming")
# Out:
# Welcome to
# Python Programming
# Welcome to
# Python Programming
# Welcome to Python Programming
# Welcome to-Python Programming

# %% [markdown]
# Question 1-3

# %%
print("Welcome", "to", sep="-")
print("Python", "Programming", end="!")
print("Welcome", "to", sep="-", end="!")
print("Python", "Programming", end="!")
# Out:
# Welcome-to
# Python Programming!Welcome-to!Python Programming!

# %% [markdown]
# Question 1-4

# %%
print('Welcome to')
print("Python Programming")
print('''Welcome to
Python Programming''')
# Out:
# Welcome to
# Python Programming
# Welcome to
# Python Programming

# %% [markdown]
# Question 2-1

# %%
name = input("Enter your name: ")
print("Hello,", name)

# When first input is your name
# Out:
# Hello, Theerayut Khongsuk

# %% [markdown]
# Question 2-1-1

# %%
age = input("Enter your age: ")
print("You are", age, "years old.")

# When first input is your age in english (e.g., twenty-five)
# Out:
# You are eighteen years old years old.

# %% [markdown]
# Question 2-2

# %%
age = input("Enter your age: ")
print("You are", age, "years old.")

# When first input is your age in digit (e.g., 25)
# Out:
# You are 18 years old.

# %% [markdown]
# Question 2-3

# %%
age = input("Enter your age: ")
print("You are", age, "years old.")
print("Next year, you will be", age + 1, "years old.")

# When first input is your age in digit (e.g., 25)
# Out:
# You are 18 years old.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 age = input("Enter your age: ")
#       2 print("You are", age, "years old.")
# ----> 3 print("Next year, you will be", age + 1, "years old.")
#       5 # When first input is your age in digit (e.g., 25)
#
# TypeError: can only concatenate str (not "int") to str

# %%
age = int(input("Enter your age: "))
print("You are", age, "years old.")
print("Next year, you will be", age + 1, "years old.")

# When first input is your age in digit (e.g., 25)
# Out:
# You are 18 years old.
# Next year, you will be 19 years old.

# %% [markdown]
# Question 2-4

# %%
age = input("Enter your age: ")
print("You are", age, "years old.")
print("Next year, you will be", int(age) + 1, "years old.")

# When first input is your age in digit (e.g., 25)
# Out:
# You are 18 years old.
# Next year, you will be 19 years old.

# %% [markdown]
# Question 2-5

# %%
name = input("Enter your name: ")
age = input("Enter your age: ")
print(name, "is", age, "years old.")
print(f"{name} is {age} years old.")
# Out:
# Sea khongsuk is 18 years old.
# Sea khongsuk is 18 years old.

# %% [markdown]
# Question 3

# %%
length = input("Enter the length: ")
width = input("Enter the width: ")
print("The area of the rectangle is:", length * width)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 length = input("Enter the length: ")
#       2 width = input("Enter the width: ")
# ----> 3 print("The area of the rectangle is:", length * width)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
length = int(input("Enter the length: "))
width = int(input("Enter the width: "))
print("The area of the rectangle is:", length * width)
# Out:
# The area of the rectangle is: 50

# %% [markdown]
# Question 4-1

# %%
a = 10
b = "Hello"
c = 5.6
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %% [markdown]
# Question 4-2

# %%
a = "Ten"
print(type(a))
a = 10.0
print(type(a))
a = 10
print(type(a))
a = a * 1 
print(type(a))
a = a * 1.0
print(type(a))
a = a * 1
print(type(a))
# Out:
# <class 'str'>
# <class 'float'>
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'float'>

# %% [markdown]
# Question 4-3

# %%
a = "25"
b = 25
print(a == b)               
print(int(a) == b) 
print(float(a) == float(b))
# Out:
# False
# True
# True

# %% [markdown]
# Question 4-4

# %%
a = 25.75
print(int(a))
# Out:
# 25

# %% [markdown]
# Question 4-5

# %%
a = "25.75"
print(int(a))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 2
#       1 a = "25.75"
# ----> 2 print(int(a))
#
# ValueError: invalid literal for int() with base 10: '25.75'

# %%
a = "25.75"
print(float(a))
# Out:
# 25.75

# %% [markdown]
# Question 5

# %%
radius = input("Enter the radius of the circle: ")
area = 3.14 * radius ** 2
print("The area of the circle is:" + area)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 radius = input("Enter the radius of the circle: ")
# ----> 2 area = 3.14 * radius ** 2
#       3 print("The area of the circle is:" + area)
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'int'

# %%
radius = float(input("Enter the radius of the circle: "))
area = 3.14 * radius ** 2
print("The area of the circle is: " + str(area))
# Out:
# The area of the circle is: 78.5

# %% [markdown]
# Question 6

# %%
quantity = int(input("Enter the number of items: "))
price_per_item = float(input("Enter the price per item: "))
total_cost = quantity * price_per_item
Shipping_cost = 0.07 * total_cost
final_price = total_cost + Shipping_cost
print("Total price:", final_price)
# Out:
# Total price: 535.0

# %% [markdown]
# Question 7

# %%
length = float(input("Enter the length of something: "))
width = float(input("Enter the width of something: "))
height = float(input("Enter the height of something: "))
Area = length * width
volume = length * width * height
print("The area of the rectangle is: " + str(Area))
print("The volume of the Box is: " + str(volume))
# Out:
# The area of the rectangle is: 50.0
# The volume of the Box is: 150.0
