# %% [markdown]
# Question 1-1

# %%
word = "Computer Programing"
print("String:", word)
print("String:", word[0])
print("String:", word[1])
print("String:", word[2])
# Out:
# String: Computer Programing
# String: C
# String: o
# String: m

# %% [markdown]
# Question 1-2

# %%
print("String:", word[:])
print("String:", word[0:])
print("String:", word[1:])
print("String:", word[2:])
print("String:", word[:0])
print("String:", word[:1])
print("String:", word[:2])
# Out:
# String: Computer Programing
# String: Computer Programing
# String: omputer Programing
# String: mputer Programing
# String:
# String: C
# String: Co

# %% [markdown]
# Question 1-3

# %%
print("String:", word[0:2])
print("String:", word[1:2])
print("String:", word[2:2])
# Out:
# String: Co
# String: o
# String:

# %% [markdown]
# Question 1-4

# %%
print("String:", word[1:-1])
print("String:", word[2:-2])
print("String:", word[3:-3])
# Out:
# String: omputer Programin
# String: mputer Programi
# String: puter Program

# %% [markdown]
# Question 1-5

# %%
print("String:", word[-1:])
print("String:", word[-2:])
print("String:", word[-3:])
# Out:
# String: g
# String: ng
# String: ing

# %% [markdown]
# Question 1-6

# %%
print("String:", word[18])
# Out:
# String: g

# %% [markdown]
# Question 2

# %%
print("Computer\nPrograming")
print("Computer\nPrograming\n\n")
print("Computer\tPrograming")
print("Computer\\Programing")
print("Computer\"Programing")
print("Computer\nPrograming\n")
# Out:
# Computer
# Programing
# Computer
# Programing
#
#
# Computer	Programing
# Computer\Programing
# Computer"Programing
# Computer
# Programing

# %% [markdown]
# Question 3-1

# %%
word = "Computer Programing"
print("Length:", len(word))
# Out:
# Length: 19

# %% [markdown]
# Question 3-2

# %%
print("String:", word.lower())
print("String:", word.upper())
print("String:", word.capitalize())
# Out:
# String: computer programing
# String: COMPUTER PROGRAMING
# String: Computer programing

# %% [markdown]
# Question 3-3

# %%
print("String:", word.replace(" ", "-"))
print("String:", word.replace("Computer", "Python"))
# Out:
# String: Computer-Programing
# String: Python Programing

# %% [markdown]
# Question 3-4

# %%
print("String:", word.split())
print("String:", word.split("o"))
print("String:", type(word.split("o")))
# Out:
# String: ['Computer', 'Programing']
# String: ['C', 'mputer Pr', 'graming']
# String: <class 'list'>

# %% [markdown]
# Question 3-5

# %%
print("Is string in word:", "ter" in word)
print("Is string in word:", "Ter" in word)
# Out:
# Is string in word: True
# Is string in word: False

# %% [markdown]
# Question 3-6

# %%
print("String:", word.lower)
# Out:
# String: <built-in method lower of str object at 0x10c1ba170>

# %% [markdown]
# Question 3-7

# %%
word1 = "Computer"
word2 = "Programing"
print("String:", word1 + word2)
print("String:", word1 + " " +  word2)
# Out:
# String: ComputerPrograming
# String: Computer Programing

# %% [markdown]
# Question 4

# %%
word = "Hello World"
print(word[0:5].upper())
print(word[6:11].lower())
print(len(word))
# Out:
# HELLO
# world
# 11

# %% [markdown]
# Question 5-1

# %%
result1 = 15 + 25
print("1) 15 + 25 =", result1)
result2 = 50 - 12
print("2) 50 - 12 =", result2)
result3 = 7 * 8
print("3) 7 * 8 =", result3)
result4 = 20 / 6
print("4) 20 / 6 =", result4)
result5 = 20 // 6
print("5) 20 // 6 =", result5)
result6 = 20 % 6
print("6) 20 % 6 =", result6)
result7 = 2 ** 5
print("7) 2 ** 5 =", result7)
# Out:
# 1) 15 + 25 = 40
# 2) 50 - 12 = 38
# 3) 7 * 8 = 56
# 4) 20 / 6 = 3.3333333333333335
# 5) 20 // 6 = 3
# 6) 20 % 6 = 2
# 7) 2 ** 5 = 32

# %% [markdown]
# Question 5-2

# %%
result = 10 + 20 * 30 // 4
print(result)
result = 10 + 20 * (30 // 4)
print(result)
result = (10 + 20) * (30 // 4)
print(result)
result = (10 + 20 * 30) // 4
print(result)
# Out:
# 160
# 150
# 210
# 152

# %% [markdown]
# Question 5-3

# %%
number = 3.9
print(number)
number = int(number)
print(number)
number = float(number)
print(number)
number = complex(number)
print(number)
# Out:
# 3.9
# 3
# 3.0
# (3+0j)

# %% [markdown]
# Question 5-4

# %%
number = int(number)
print(number)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 number = int(number)
#       2 print(number)
#
# TypeError: can't convert complex to int

# %%
number = int(number.real)
print(number)
print(number)
# Out:
# 3
# 3

# %% [markdown]
# Question 5-5

# %%
number = 2.5
print(number)
print(round(number))
number = 3.5
print(number)
print(round(number))
number = 10 / 3
print(number)
print(round(number))
print(round(number, 2))
# Out:
# 2.5
# 2
# 3.5
# 4
# 3.3333333333333335
# 3
# 3.33

# %% [markdown]
# Question 6

# %%
#At starting point, the initial velocity is 0 m/s.#
Velocity = float(input("Enter Velocity (m/s): "))
Acceleration = float(input("Enter Acceleration (m/s^2): "))
Time = (Velocity - 0) / Acceleration
print("Time:", round(Time, 2), "seconds")
# Out:
# Time: 16.67 seconds
